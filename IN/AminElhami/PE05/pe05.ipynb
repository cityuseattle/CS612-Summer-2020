# %%
import requests
import pandas as pd
url = 'http://jsonplaceholder.typicode.com/users'
res = requests.get(url)
all_users = res.json()
df = pd.DataFrame(all_users, columns=['username','email'])
df
zipcode0 = [all_users[0]['address']['zipcode']]
zipcode1 = [all_users[1]['address']['zipcode']]
zipcode2 = [all_users[2]['address']['zipcode']]
zipcode3 = [all_users[3]['address']['zipcode']]
zipcode4 = [all_users[4]['address']['zipcode']]
zipcode5 = [all_users[5]['address']['zipcode']]
zipcode6 = [all_users[6]['address']['zipcode']]
zipcode7 = [all_users[7]['address']['zipcode']]
zipcode8 = [all_users[8]['address']['zipcode']]
zipcode9 = [all_users[9]['address']['zipcode']]

zipcodes = [zipcode0, zipcode1, zipcode2, zipcode3, zipcode4, zipcode5, zipcode6, zipcode7, zipcode8, zipcode9]

lat0 = [all_users[0]['address']['geo']['lat']]
lat1 = [all_users[1]['address']['geo']['lat']]
lat2 = [all_users[2]['address']['geo']['lat']]
lat3 = [all_users[3]['address']['geo']['lat']]
lat4 = [all_users[4]['address']['geo']['lat']]
lat5 = [all_users[5]['address']['geo']['lat']]
lat6 = [all_users[6]['address']['geo']['lat']]
lat7 = [all_users[7]['address']['geo']['lat']]
lat8 = [all_users[8]['address']['geo']['lat']]
lat9 = [all_users[9]['address']['geo']['lat']]

lats = [lat0, lat1, lat2, lat3, lat4, lat5, lat6, lat7, lat8, lat9]
lats

lng0 = [all_users[0]['address']['geo']['lng']]
lng1 = [all_users[1]['address']['geo']['lng']]
lng2 = [all_users[2]['address']['geo']['lng']]
lng3 = [all_users[3]['address']['geo']['lng']]
lng4 = [all_users[4]['address']['geo']['lng']]
lng5 = [all_users[5]['address']['geo']['lng']]
lng6 = [all_users[6]['address']['geo']['lng']]
lng7 = [all_users[7]['address']['geo']['lng']]
lng8 = [all_users[8]['address']['geo']['lng']]
lng9 = [all_users[9]['address']['geo']['lng']]

lngs = [lng0, lng1, lng2, lng3, lng4, lng5, lng6, lng7, lng8, lng9]
lngs

comp0 = [all_users[0]['company']['name']]
comp1 = [all_users[1]['company']['name']]
comp2 = [all_users[2]['company']['name']]
comp3 = [all_users[3]['company']['name']]
comp4 = [all_users[4]['company']['name']]
comp5 = [all_users[5]['company']['name']]
comp6 = [all_users[6]['company']['name']]
comp7 = [all_users[7]['company']['name']]
comp8 = [all_users[8]['company']['name']]
comp9 = [all_users[9]['company']['name']]

comps = [comp0, comp1, comp2, comp3, comp4, comp5, comp6, comp7, comp8, comp9]
comps



df['zipcodes'] = zipcodes
df['lngs'] = lngs
df['lats'] = lats
df['Company'] = comps

df_a = df[(df['lngs'] >0) & (df['lats'] <0)]
df_a
df_a.to_csv(r'output.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-a18b045705af> in <module>
#      68 df['Company'] = comps
#      69
# ---> 70 df_a = df[(df['lngs'] >0) & (df['lats'] <0)]
#      71 df_a
#      72 df_a.to_csv(r'output.csv')
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#     368         rvalues = extract_array(other, extract_numpy=True)
#     369
# --> 370         res_values = comparison_op(lvalues, rvalues, op)
#     371
#     372         return self._construct_result(res_values, name=res_name)
#
# ...
