# %%
import numpy as np

# %%
import pandas as pd

# %%
ex1 = pd.Series([0, np.nan, '', None])

# %%
ex1
# Out:
# 0       0
# 1     NaN
# 2
# 3    None
# dtype: object

# %%
ex2 = np.array([2, np.nan, 6, 8])
ex2.sum(), ex2.min(), ex2.max()
# Out:
# (nan, nan, nan)

# %%
ex1.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# dtype: bool

# %%
ex1[ex1.notnull()]
# Out:
# 0    0
# 2
# dtype: object

# %%
ex1.dropna()
# Out:
# 0    0
# 2
# dtype: object

# %%
ex3 = pd.DataFrame([
    [1, np.nan, 7],
    [2, 5,      8],
    [np.nan, 6, 9]
])

# %%
ex3.dropna()
# Out:
#      0    1  2
# 1  2.0  5.0  8

# %%
ex3.fillna(0)
# Out:
#      0    1  2
# 0  1.0  0.0  7
# 1  2.0  5.0  8
# 2  0.0  6.0  9

# %%
dup = pd.DataFrame({
    'letters': ['A','B']*2 +['B'],
    'numbers': [1,2,1,3,3]
})

# %%
dup
# Out:
#   letters  numbers
# 0       A        1
# 1       B        2
# 2       A        1
# 3       B        3
# 4       B        3

# %%
dup.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# dtype: bool

# %%
dup.drop_duplicates()
# Out:
#   letters  numbers
# 0       A        1
# 1       B        2
# 3       B        3

# %%
dup.drop_duplicates(['letters'])
# Out:
#   letters  numbers
# 0       A        1
# 1       B        2

# %%
sales = pd.read_csv('../Module5/sales_data_sample.csv', encoding='latin')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-a42f4e16db2f> in <module>
# ----> 1 sales = pd.read_csv('../Module5/sales_data_sample.csv', encoding='latin')
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
data = pd.DataFrame(sales.loc[:50,['ORDERNUMBER', 'QUANTITYORDERED', 'SALES', 'CUSTOMERNAME', 'ADDRESSLINE1', 'POSTALCODE', 'STATUS']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-ac6d49e8a316> in <module>
# ----> 1 data = pd.DataFrame(sales.loc[:50,['ORDERNUMBER', 'QUANTITYORDERED', 'SALES', 'CUSTOMERNAME', 'ADDRESSLINE1', 'POSTALCODE', 'STATUS']])
#
# NameError: name 'sales' is not defined

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-c5d84736ba45> in <module>
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
data.rename(columns={'ORDERNUMBER':'ORDER_ID', 'ADDRESSLINE1': 'ADDRESS'}, inplace=True)
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-c01852bcf8f8> in <module>
# ----> 1 data.rename(columns={'ORDERNUMBER':'ORDER_ID', 'ADDRESSLINE1': 'ADDRESS'}, inplace=True)
#       2 data
#
# NameError: name 'data' is not defined

# %%
data.columns[data.column != 'STATUS']
data[data['SALES'] >5000]
data[data['CUSTOMERNAME'].str.contain('Ltd')]
data.loc[(data.SALES >5000) 'STATUS']= 'Canceled'
# Out:
#   File "<ipython-input-23-6370054c1fd9>", line 4
#     data.loc[(data.SALES >5000) 'STATUS']= 'Canceled'
#                                        ^
# SyntaxError: invalid syntax

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-c5d84736ba45> in <module>
# ----> 1 data
#
# NameError: name 'data' is not defined
