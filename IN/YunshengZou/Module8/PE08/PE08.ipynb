# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Heights.csv')
data
# Out:
#     Husband  Wife
# 0       186   175
# 1       180   168
# 2       160   154
# 3       186   166
# 4       163   162
# ..      ...   ...
# 91      173   161
# 92      164   146
# 93      181   168
# 94      187   178
# 95      181   170
#
# [96 rows x 2 columns]

# %%
#Problem A
ax = plt.subplot()
x = data['Husband']
y = data['Wife']
ax.scatter(x,y)
ax.set_xlabel('Husband',fontsize=12)
ax.set_ylabel('wife',fontsize=12)
ax.set_title('Scatter Plot of Heights')
a,b = np.polyfit(x,y,deg=1)
y_est = a * x + b
ax.plot(x,y_est,'-')

# %%
x = np.arange(-5,5,0.1,dtype=float)
x
# Out:
# array([-5.00000000e+00, -4.90000000e+00, -4.80000000e+00, -4.70000000e+00,
#        -4.60000000e+00, -4.50000000e+00, -4.40000000e+00, -4.30000000e+00,
#        -4.20000000e+00, -4.10000000e+00, -4.00000000e+00, -3.90000000e+00,
#        -3.80000000e+00, -3.70000000e+00, -3.60000000e+00, -3.50000000e+00,
#        -3.40000000e+00, -3.30000000e+00, -3.20000000e+00, -3.10000000e+00,
#        -3.00000000e+00, -2.90000000e+00, -2.80000000e+00, -2.70000000e+00,
#        -2.60000000e+00, -2.50000000e+00, -2.40000000e+00, -2.30000000e+00,
#        -2.20000000e+00, -2.10000000e+00, -2.00000000e+00, -1.90000000e+00,
#        -1.80000000e+00, -1.70000000e+00, -1.60000000e+00, -1.50000000e+00,
#        -1.40000000e+00, -1.30000000e+00, -1.20000000e+00, -1.10000000e+00,
#        -1.00000000e+00, -9.00000000e-01, -8.00000000e-01, -7.00000000e-01,
#        -6.00000000e-01, -5.00000000e-01, -4.00000000e-01, -3.00000000e-01,
# ...

# %%
import math
x = np.arange(-5,5,0.1)
y1 = -(1/3)*x+1.5
y2 = 0.02*x*(x-1)*(x+1)+1
y3 = np.array([])
for a in x: y3 = np.append(y3,2*math.exp(-a*a))
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax1.plot(x,y1,color='g',linestyle=':')
ax2.plot(x,y2,color='y',linestyle='--')
ax3.plot(x,y3,color='r',linestyle='-')
