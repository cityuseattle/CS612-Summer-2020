# %%
import numpy as np 
import pandas as pd 
import seaborn as sb 
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-c4be2bf31c91> in <module>
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import seaborn as sb
#       4 import matplotlib.pyplot as plt
#
# C:\Python36-32\lib\site-packages\seaborn\__init__.py in <module>
#       4
#       5 # Import seaborn objects
# ----> 6 from .rcmod import *
#       7 from .utils import *
#       8 from .palettes import *
#
# C:\Python36-32\lib\site-packages\seaborn\rcmod.py in <module>
#       5 import matplotlib as mpl
#       6 from cycler import cycler
# ----> 7 from . import palettes, _orig_rc_params
#       8
#       9
#
# C:\Python36-32\lib\site-packages\seaborn\palettes.py in <module>
#       7 from .external import husl
#       8
# ----> 9 from .utils import desaturate, set_hls_values, get_color_cycle
#      10 from .colors import xkcd_rgb, crayons
#      11
#
# ...
