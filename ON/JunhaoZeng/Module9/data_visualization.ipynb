# %%
import numpy as np 
import pandas as pd
import seaborn as sb 
import matplotlib.pyplot as plt

# %%
x = np.linspace(-np.pi, np.pi, 256, endpoint=True)
c, s = np.cos(x), np.sin(x)

# %%
plt.plot(x, c, '-c')
plt.plot(x, s, '--m')

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

y = [1 , 4, 9, 16, 25, 36, 49, 64]
x1 = [1, 16, 30, 42, 55, 68, 77, 88]
x2 = [1, 6, 12, 18, 28, 40, 52, 65]

l1 = ax.plot(x1, y, 'bs-')
l2 = ax.plot(x2, y, 'ro--')
ax.legend(labels=('AMZ', 'MSFT'), loc='lower right')
ax.set_title("Stock Market")
ax.set_xlabel('Time')
ax.set_ylabel('USD')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.subplot(2,2,1, fc='r')
plt.subplot(2,2,2, fc='g')
plt.subplot(2,2,3, fc='b')
plt.subplot(2,2,4, fc='y')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig1 = plt.figure()

ax1 = fig1.add_subploy(1,1,1)
ax2 = fig1.add_subploy(2,2,1)

ax.scatter(np.linspace(0, 1, 5), np.linspace(0, 5 ,5))
ax2.plot([1,2])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-dc5faf90767a> in <module>
#       1 fig1 = plt.figure()
#       2
# ----> 3 ax1 = fig1.add_subploy(1,1,1)
#       4 ax2 = fig1.add_subploy(2,2,1)
#       5
#
# AttributeError: 'Figure' object has no attribute 'add_subploy'

# %%
x = np.arange(0, np.pi*2, 0.05)
y = np.sin(x)
z = np.cos(x)

fig2 = plt.figure()

axes1 = fig2.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig2.add_axes([0.55, 0.55, 0.3, 0.3])

axes1.plot(x, y, 'b')
axes2.plot(x, z, 'r')
axes1.set_title('sine')
axes2.set_title('cosine')
plt.show()

# %%
a = np.random.random((8,8))

plt.imshow(a, cmap='autumn')
plt.show()

# %%
def f(x,y): return (1-x/2+x**5+y**3)*np.exp(-x**2-y**2)

n = 256
x=np.linspace(-3, 3, n)
y=np.linspace(-3, 3, n)
X, Y = np.meshgrid(x,y)

plt.contourf(X, Y, f(X,Y), 8, alpha=.75, cmap='jet')
c = plt.contour(X, Y, f(X,Y), 8, color='black', linwidth=.5)

plt.show()

# %%
n = 512
x = np.random.normal(0,1,n)
y = np.random.normal(0,1,n)

plt.scatter(x, y, color='c')
plt.show()

# %%
n=12
x=np.arange(n)
y1 = (1-x/float(n)) * np.random.uniform(0.5, 1.0, n)
y2 = (1-x/float(n)) * np.random.uniform(0.5, 1.0, n)

plt.bar(x, +y1, facecolor='#9999ff', edgecolor=['green', 'red'])
plt.bar(x, -y2, facecolor='#ff9999', edgecolor='white')

for x, y in zip(x, y1):
    plt.text(x+0.4, y+0.5, f"{y:.2f}", ha='center', va='center')

plt.ylim(-1.25, +1.25)
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax= Axes3D(fig)
x = np.arange(-4, 4, 0.25)
y = np.arange(-4, 4, 0.25)
x, y = np.meshgrid(x,y)
r = np.sqrt(x**2, y**2)
z = np.sin(r)

ax.plot_surface(x, y, z, rstride=1, cstride=1, cmap='winter')
plt.show()

# %%
df = sb.load_dataset('tips')
sb.relpot(x="total_bill", y="tip", data=df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-1b32dcfd458e> in <module>
# ----> 1 df = sb.load_dataset('tips')
#       2 sb.relpot(x="total_bill", y="tip", data=df)
#
# NameError: name 'sb' is not defined

# %%
sb.relplot(x="total_bill", y="tip", hue=df.day.tolist(), data=df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-ee91de4da6fe> in <module>
# ----> 1 sb.relplot(x="total_bill", y="tip", hue=df.day.tolist(), data=df)
#
# NameError: name 'sb' is not defined

# %%
sb.set(style='whitegrid')
sb.relplot(x="total_bill", y="tip", hue=df.day.tolist(), data=df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-a0b1ef5e58a5> in <module>
# ----> 1 sb.set(style='whitegrid')
#       2 sb.relplot(x="total_bill", y="tip", hue=df.day.tolist(), data=df)
#
# NameError: name 'sb' is not defined

# %%
sb.palplot(sb.color_palette("muted"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-b0a8ead0bb6a> in <module>
# ----> 1 sb.palplot(sb.color_palette("muted"))
#
# NameError: name 'sb' is not defined

# %%
sb.palplot(sb.color_palette("husl", 8))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-1c685de12aca> in <module>
# ----> 1 sb.palplot(sb.color_palette("husl", 8))
#
# NameError: name 'sb' is not defined

# %%
sb.palplot(sb.color_palette("Blues"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-8e88276fab62> in <module>
# ----> 1 sb.palplot(sb.color_palette("Blues"))
#
# NameError: name 'sb' is not defined

# %%
sb.catplot(x="day", y="total_bill", data=df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-0e2516ee847e> in <module>
# ----> 1 sb.catplot(x="day", y="total_bill", data=df)
#
# NameError: name 'sb' is not defined

# %%
dist = np.random.normal(loc=5, size=100, scale=2)
sb.distplot(dist)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-d252857111da> in <module>
#       1 dist = np.random.normal(loc=5, size=100, scale=2)
# ----> 2 sb.distplot(dist)
#
# NameError: name 'sb' is not defined

# %%
fg = sb.FacetGrid(df, col="time")
fg.map(plt.hist, "tip")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-d8f643333796> in <module>
# ----> 1 fg = sb.FacetGrid(df, col="time")
#       2 fg.map(plt.hist, "tip")
#
# NameError: name 'sb' is not defined

# %%
iris = sb.load_dataset("iris")
pg = sb.PairGrid(iris, hue="specise")
pg.add_legend()
pg.map(plt.scatter)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-ef6baef7b3ad> in <module>
# ----> 1 iris = sb.load_dataset("iris")
#       2 pg = sb.PairGrid(iris, hue="specise")
#       3 pg.add_legend()
#       4 pg.map(plt.scatter)
#
# NameError: name 'sb' is not defined

# %%
flight_long = sb.load_dataset("flights")
flight = flight_long.pivot("month", "year", "passengers")

f, ax = plt.subplot(figsize=(12,9))
sb.heatmap(flights, annot=True, fmt="d", linewidths=.5, ax=ax)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-45d6d66e435d> in <module>
# ----> 1 flight_long = sb.load_dataset("flights")
#       2 flight = flight_long.pivot("month", "year", "passengers")
#       3
#       4 f, ax = plt.subplot(figsize=(12,9))
#       5 sb.heatmap(flights, annot=True, fmt="d", linewidths=.5, ax=ax)
#
# NameError: name 'sb' is not defined
